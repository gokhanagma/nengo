# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book "Neural Engineering"](
# https://www.amazon.com/Neural-Engineering-Representation-Neurobiological-Computational/dp/0262550601).
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="754149290" href="javascript:toggle_input_754149290()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_754149290;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_754149290 = document.getElementById("754149290");
#                 var cell = link_754149290;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_754149290;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_754149290 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_754149290 = cell.previousElementSibling;
#                 }
#                 input_754149290.style.display = "none"; // hide
#
#                 toggle_input_754149290 = function() {
#                     if (input_754149290.style.display == "none") {
#                         input_754149290.style.display = ""; // show
#                         link_754149290.innerHTML = "Hide Input";
#                     } else {
#                         input_754149290.style.display = "none"; // hide
#                         link_754149290.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_754149290 = $("a[id='754149290']");
#                 var cell_754149290 = link_754149290.parents("div.cell:first");
#                 if (cell_754149290.length == 0) {
#                     cell_754149290 = link_754149290.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_754149290 = cell_754149290.children("div.input");
#                 if (input_754149290.length == 0) {
#                     input_754149290 = cell_754149290.prev("div.nbinput");
#                 }
#                 input_754149290.hide();
#
#                 toggle_input_754149290 = function() {
#                     if (input_754149290.is(':hidden')) {
#                         input_754149290.slideDown();
#                         link_754149290[0].innerHTML = "Hide Input";
#                     } else {
#                         input_754149290.slideUp();
#                         link_754149290[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1118779554" href="javascript:toggle_input_1118779554()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1118779554;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1118779554 = document.getElementById("1118779554");
#                 var cell = link_1118779554;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1118779554;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1118779554 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1118779554 = cell.previousElementSibling;
#                 }
#                 input_1118779554.style.display = "none"; // hide
#
#                 toggle_input_1118779554 = function() {
#                     if (input_1118779554.style.display == "none") {
#                         input_1118779554.style.display = ""; // show
#                         link_1118779554.innerHTML = "Hide Input";
#                     } else {
#                         input_1118779554.style.display = "none"; // hide
#                         link_1118779554.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1118779554 = $("a[id='1118779554']");
#                 var cell_1118779554 = link_1118779554.parents("div.cell:first");
#                 if (cell_1118779554.length == 0) {
#                     cell_1118779554 = link_1118779554.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1118779554 = cell_1118779554.children("div.input");
#                 if (input_1118779554.length == 0) {
#                     input_1118779554 = cell_1118779554.prev("div.nbinput");
#                 }
#                 input_1118779554.hide();
#
#                 toggle_input_1118779554 = function() {
#                     if (input_1118779554.is(':hidden')) {
#                         input_1118779554.slideDown();
#                         link_1118779554[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1118779554.slideUp();
#                         link_1118779554[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")
hide_input()
# Out:
#         <a id="1943095268" href="javascript:toggle_input_1943095268()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1943095268;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1943095268 = document.getElementById("1943095268");
#                 var cell = link_1943095268;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1943095268;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1943095268 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1943095268 = cell.previousElementSibling;
#                 }
#                 input_1943095268.style.display = "none"; // hide
#
#                 toggle_input_1943095268 = function() {
#                     if (input_1943095268.style.display == "none") {
#                         input_1943095268.style.display = ""; // show
#                         link_1943095268.innerHTML = "Hide Input";
#                     } else {
#                         input_1943095268.style.display = "none"; // hide
#                         link_1943095268.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1943095268 = $("a[id='1943095268']");
#                 var cell_1943095268 = link_1943095268.parents("div.cell:first");
#                 if (cell_1943095268.length == 0) {
#                     cell_1943095268 = link_1943095268.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1943095268 = cell_1943095268.children("div.input");
#                 if (input_1943095268.length == 0) {
#                     input_1943095268 = cell_1943095268.prev("div.nbinput");
#                 }
#                 input_1943095268.hide();
#
#                 toggle_input_1943095268 = function() {
#                     if (input_1943095268.is(':hidden')) {
#                         input_1943095268.slideDown();
#                         link_1943095268[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1943095268.slideUp();
#                         link_1943095268[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel("Neuron")
ax.set_xlabel("Time (s)")
hide_input()
# Out:
#         <a id="735075744" href="javascript:toggle_input_735075744()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_735075744;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_735075744 = document.getElementById("735075744");
#                 var cell = link_735075744;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_735075744;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_735075744 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_735075744 = cell.previousElementSibling;
#                 }
#                 input_735075744.style.display = "none"; // hide
#
#                 toggle_input_735075744 = function() {
#                     if (input_735075744.style.display == "none") {
#                         input_735075744.style.display = ""; // show
#                         link_735075744.innerHTML = "Hide Input";
#                     } else {
#                         input_735075744.style.display = "none"; // hide
#                         link_735075744.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_735075744 = $("a[id='735075744']");
#                 var cell_735075744 = link_735075744.parents("div.cell:first");
#                 if (cell_735075744.length == 0) {
#                     cell_735075744 = link_735075744.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_735075744 = cell_735075744.children("div.input");
#                 if (input_735075744.length == 0) {
#                     input_735075744 = cell_735075744.prev("div.nbinput");
#                 }
#                 input_735075744.hide();
#
#                 toggle_input_735075744 = function() {
#                     if (input_735075744.is(':hidden')) {
#                         input_735075744.slideDown();
#                         link_735075744[0].innerHTML = "Hide Input";
#                     } else {
#                         input_735075744.slideUp();
#                         link_735075744[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons)
)
hide_input()
# Out:
#         <a id="1949146169" href="javascript:toggle_input_1949146169()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1949146169;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1949146169 = document.getElementById("1949146169");
#                 var cell = link_1949146169;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1949146169;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1949146169 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1949146169 = cell.previousElementSibling;
#                 }
#                 input_1949146169.style.display = "none"; // hide
#
#                 toggle_input_1949146169 = function() {
#                     if (input_1949146169.style.display == "none") {
#                         input_1949146169.style.display = ""; // show
#                         link_1949146169.innerHTML = "Hide Input";
#                     } else {
#                         input_1949146169.style.display = "none"; // hide
#                         link_1949146169.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1949146169 = $("a[id='1949146169']");
#                 var cell_1949146169 = link_1949146169.parents("div.cell:first");
#                 if (cell_1949146169.length == 0) {
#                     cell_1949146169 = link_1949146169.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1949146169 = cell_1949146169.children("div.input");
#                 if (input_1949146169.length == 0) {
#                     input_1949146169 = cell_1949146169.prev("div.nbinput");
#                 }
#                 input_1949146169.hide();
#
#                 toggle_input_1949146169 = function() {
#                     if (input_1949146169.is(':hidden')) {
#                         input_1949146169.slideDown();
#                         link_1949146169[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1949146169.slideUp();
#                         link_1949146169[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1380137634" href="javascript:toggle_input_1380137634()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1380137634;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1380137634 = document.getElementById("1380137634");
#                 var cell = link_1380137634;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1380137634;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1380137634 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1380137634 = cell.previousElementSibling;
#                 }
#                 input_1380137634.style.display = "none"; // hide
#
#                 toggle_input_1380137634 = function() {
#                     if (input_1380137634.style.display == "none") {
#                         input_1380137634.style.display = ""; // show
#                         link_1380137634.innerHTML = "Hide Input";
#                     } else {
#                         input_1380137634.style.display = "none"; // hide
#                         link_1380137634.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1380137634 = $("a[id='1380137634']");
#                 var cell_1380137634 = link_1380137634.parents("div.cell:first");
#                 if (cell_1380137634.length == 0) {
#                     cell_1380137634 = link_1380137634.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1380137634 = cell_1380137634.children("div.input");
#                 if (input_1380137634.length == 0) {
#                     input_1380137634 = cell_1380137634.prev("div.nbinput");
#                 }
#                 input_1380137634.hide();
#
#                 toggle_input_1380137634 = function() {
#                     if (input_1380137634.is(':hidden')) {
#                         input_1380137634.slideDown();
#                         link_1380137634[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1380137634.slideUp();
#                         link_1380137634[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="985542349" href="javascript:toggle_input_985542349()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_985542349;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_985542349 = document.getElementById("985542349");
#                 var cell = link_985542349;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_985542349;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_985542349 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_985542349 = cell.previousElementSibling;
#                 }
#                 input_985542349.style.display = "none"; // hide
#
#                 toggle_input_985542349 = function() {
#                     if (input_985542349.style.display == "none") {
#                         input_985542349.style.display = ""; // show
#                         link_985542349.innerHTML = "Hide Input";
#                     } else {
#                         input_985542349.style.display = "none"; // hide
#                         link_985542349.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_985542349 = $("a[id='985542349']");
#                 var cell_985542349 = link_985542349.parents("div.cell:first");
#                 if (cell_985542349.length == 0) {
#                     cell_985542349 = link_985542349.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_985542349 = cell_985542349.children("div.input");
#                 if (input_985542349.length == 0) {
#                     input_985542349 = cell_985542349.prev("div.nbinput");
#                 }
#                 input_985542349.hide();
#
#                 toggle_input_985542349 = function() {
#                     if (input_985542349.is(':hidden')) {
#                         input_985542349.slideDown();
#                         link_985542349[0].innerHTML = "Hide Input";
#                     } else {
#                         input_985542349.slideUp();
#                         link_985542349[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1007284113" href="javascript:toggle_input_1007284113()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1007284113;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1007284113 = document.getElementById("1007284113");
#                 var cell = link_1007284113;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1007284113;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1007284113 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1007284113 = cell.previousElementSibling;
#                 }
#                 input_1007284113.style.display = "none"; // hide
#
#                 toggle_input_1007284113 = function() {
#                     if (input_1007284113.style.display == "none") {
#                         input_1007284113.style.display = ""; // show
#                         link_1007284113.innerHTML = "Hide Input";
#                     } else {
#                         input_1007284113.style.display = "none"; // hide
#                         link_1007284113.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1007284113 = $("a[id='1007284113']");
#                 var cell_1007284113 = link_1007284113.parents("div.cell:first");
#                 if (cell_1007284113.length == 0) {
#                     cell_1007284113 = link_1007284113.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1007284113 = cell_1007284113.children("div.input");
#                 if (input_1007284113.length == 0) {
#                     input_1007284113 = cell_1007284113.prev("div.nbinput");
#                 }
#                 input_1007284113.hide();
#
#                 toggle_input_1007284113 = function() {
#                     if (input_1007284113.is(':hidden')) {
#                         input_1007284113.slideDown();
#                         link_1007284113[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1007284113.slideUp();
#                         link_1007284113[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize="medium")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1009661522" href="javascript:toggle_input_1009661522()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1009661522;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1009661522 = document.getElementById("1009661522");
#                 var cell = link_1009661522;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1009661522;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1009661522 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1009661522 = cell.previousElementSibling;
#                 }
#                 input_1009661522.style.display = "none"; // hide
#
#                 toggle_input_1009661522 = function() {
#                     if (input_1009661522.style.display == "none") {
#                         input_1009661522.style.display = ""; // show
#                         link_1009661522.innerHTML = "Hide Input";
#                     } else {
#                         input_1009661522.style.display = "none"; // hide
#                         link_1009661522.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1009661522 = $("a[id='1009661522']");
#                 var cell_1009661522 = link_1009661522.parents("div.cell:first");
#                 if (cell_1009661522.length == 0) {
#                     cell_1009661522 = link_1009661522.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1009661522 = cell_1009661522.children("div.input");
#                 if (input_1009661522.length == 0) {
#                     input_1009661522 = cell_1009661522.prev("div.nbinput");
#                 }
#                 input_1009661522.hide();
#
#                 toggle_input_1009661522 = function() {
#                     if (input_1009661522.is(':hidden')) {
#                         input_1009661522.slideDown();
#                         link_1009661522[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1009661522.slideUp();
#                         link_1009661522[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="928843581" href="javascript:toggle_input_928843581()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_928843581;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_928843581 = document.getElementById("928843581");
#                 var cell = link_928843581;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_928843581;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_928843581 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_928843581 = cell.previousElementSibling;
#                 }
#                 input_928843581.style.display = "none"; // hide
#
#                 toggle_input_928843581 = function() {
#                     if (input_928843581.style.display == "none") {
#                         input_928843581.style.display = ""; // show
#                         link_928843581.innerHTML = "Hide Input";
#                     } else {
#                         input_928843581.style.display = "none"; // hide
#                         link_928843581.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_928843581 = $("a[id='928843581']");
#                 var cell_928843581 = link_928843581.parents("div.cell:first");
#                 if (cell_928843581.length == 0) {
#                     cell_928843581 = link_928843581.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_928843581 = cell_928843581.children("div.input");
#                 if (input_928843581.length == 0) {
#                     input_928843581 = cell_928843581.prev("div.nbinput");
#                 }
#                 input_928843581.hide();
#
#                 toggle_input_928843581 = function() {
#                     if (input_928843581.is(':hidden')) {
#                         input_928843581.slideDown();
#                         link_928843581[0].innerHTML = "Hide Input";
#                     } else {
#                         input_928843581.slideUp();
#                         link_928843581[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="10133240" href="javascript:toggle_input_10133240()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_10133240;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_10133240 = document.getElementById("10133240");
#                 var cell = link_10133240;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_10133240;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_10133240 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_10133240 = cell.previousElementSibling;
#                 }
#                 input_10133240.style.display = "none"; // hide
#
#                 toggle_input_10133240 = function() {
#                     if (input_10133240.style.display == "none") {
#                         input_10133240.style.display = ""; // show
#                         link_10133240.innerHTML = "Hide Input";
#                     } else {
#                         input_10133240.style.display = "none"; // hide
#                         link_10133240.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_10133240 = $("a[id='10133240']");
#                 var cell_10133240 = link_10133240.parents("div.cell:first");
#                 if (cell_10133240.length == 0) {
#                     cell_10133240 = link_10133240.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_10133240 = cell_10133240.children("div.input");
#                 if (input_10133240.length == 0) {
#                     input_10133240 = cell_10133240.prev("div.nbinput");
#                 }
#                 input_10133240.hide();
#
#                 toggle_input_10133240 = function() {
#                     if (input_10133240.is(':hidden')) {
#                         input_10133240.slideDown();
#                         link_10133240[0].innerHTML = "Hide Input";
#                     } else {
#                         input_10133240.slideUp();
#                         link_10133240[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color="k")
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color="k")
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color="k")
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="712315977" href="javascript:toggle_input_712315977()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_712315977;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_712315977 = document.getElementById("712315977");
#                 var cell = link_712315977;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_712315977;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_712315977 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_712315977 = cell.previousElementSibling;
#                 }
#                 input_712315977.style.display = "none"; // hide
#
#                 toggle_input_712315977 = function() {
#                     if (input_712315977.style.display == "none") {
#                         input_712315977.style.display = ""; // show
#                         link_712315977.innerHTML = "Hide Input";
#                     } else {
#                         input_712315977.style.display = "none"; // hide
#                         link_712315977.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_712315977 = $("a[id='712315977']");
#                 var cell_712315977 = link_712315977.parents("div.cell:first");
#                 if (cell_712315977.length == 0) {
#                     cell_712315977 = link_712315977.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_712315977 = cell_712315977.children("div.input");
#                 if (input_712315977.length == 0) {
#                     input_712315977 = cell_712315977.prev("div.nbinput");
#                 }
#                 input_712315977.hide();
#
#                 toggle_input_712315977 = function() {
#                     if (input_712315977.is(':hidden')) {
#                         input_712315977.slideDown();
#                         link_712315977[0].innerHTML = "Hide Input";
#                     } else {
#                         input_712315977.slideUp();
#                         link_712315977[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel("Time (s)")

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
hide_input()
# Out:
#         <a id="395222613" href="javascript:toggle_input_395222613()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_395222613;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_395222613 = document.getElementById("395222613");
#                 var cell = link_395222613;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_395222613;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_395222613 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_395222613 = cell.previousElementSibling;
#                 }
#                 input_395222613.style.display = "none"; // hide
#
#                 toggle_input_395222613 = function() {
#                     if (input_395222613.style.display == "none") {
#                         input_395222613.style.display = ""; // show
#                         link_395222613.innerHTML = "Hide Input";
#                     } else {
#                         input_395222613.style.display = "none"; // hide
#                         link_395222613.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_395222613 = $("a[id='395222613']");
#                 var cell_395222613 = link_395222613.parents("div.cell:first");
#                 if (cell_395222613.length == 0) {
#                     cell_395222613 = link_395222613.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_395222613 = cell_395222613.children("div.input");
#                 if (input_395222613.length == 0) {
#                     input_395222613 = cell_395222613.prev("div.nbinput");
#                 }
#                 input_395222613.hide();
#
#                 toggle_input_395222613 = function() {
#                     if (input_395222613.is(':hidden')) {
#                         input_395222613.slideDown();
#                         link_395222613[0].innerHTML = "Hide Input";
#                     } else {
#                         input_395222613.slideUp();
#                         link_395222613[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
