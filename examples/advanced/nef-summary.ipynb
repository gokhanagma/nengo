# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book "Neural Engineering"](
# https://www.amazon.com/Neural-Engineering-Representation-Neurobiological-Computational/dp/0262550601).
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="965111596" href="javascript:toggle_input_965111596()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_965111596;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_965111596 = document.getElementById("965111596");
#                 var cell = link_965111596;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_965111596;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_965111596 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_965111596 = cell.previousElementSibling;
#                 }
#                 input_965111596.style.display = "none"; // hide
#
#                 toggle_input_965111596 = function() {
#                     if (input_965111596.style.display == "none") {
#                         input_965111596.style.display = ""; // show
#                         link_965111596.innerHTML = "Hide Input";
#                     } else {
#                         input_965111596.style.display = "none"; // hide
#                         link_965111596.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_965111596 = $("a[id='965111596']");
#                 var cell_965111596 = link_965111596.parents("div.cell:first");
#                 if (cell_965111596.length == 0) {
#                     cell_965111596 = link_965111596.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_965111596 = cell_965111596.children("div.input");
#                 if (input_965111596.length == 0) {
#                     input_965111596 = cell_965111596.prev("div.nbinput");
#                 }
#                 input_965111596.hide();
#
#                 toggle_input_965111596 = function() {
#                     if (input_965111596.is(':hidden')) {
#                         input_965111596.slideDown();
#                         link_965111596[0].innerHTML = "Hide Input";
#                     } else {
#                         input_965111596.slideUp();
#                         link_965111596[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1686122332" href="javascript:toggle_input_1686122332()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1686122332;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1686122332 = document.getElementById("1686122332");
#                 var cell = link_1686122332;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1686122332;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1686122332 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1686122332 = cell.previousElementSibling;
#                 }
#                 input_1686122332.style.display = "none"; // hide
#
#                 toggle_input_1686122332 = function() {
#                     if (input_1686122332.style.display == "none") {
#                         input_1686122332.style.display = ""; // show
#                         link_1686122332.innerHTML = "Hide Input";
#                     } else {
#                         input_1686122332.style.display = "none"; // hide
#                         link_1686122332.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1686122332 = $("a[id='1686122332']");
#                 var cell_1686122332 = link_1686122332.parents("div.cell:first");
#                 if (cell_1686122332.length == 0) {
#                     cell_1686122332 = link_1686122332.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1686122332 = cell_1686122332.children("div.input");
#                 if (input_1686122332.length == 0) {
#                     input_1686122332 = cell_1686122332.prev("div.nbinput");
#                 }
#                 input_1686122332.hide();
#
#                 toggle_input_1686122332 = function() {
#                     if (input_1686122332.is(':hidden')) {
#                         input_1686122332.slideDown();
#                         link_1686122332[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1686122332.slideUp();
#                         link_1686122332[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")
hide_input()
# Out:
#         <a id="1983238306" href="javascript:toggle_input_1983238306()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1983238306;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1983238306 = document.getElementById("1983238306");
#                 var cell = link_1983238306;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1983238306;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1983238306 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1983238306 = cell.previousElementSibling;
#                 }
#                 input_1983238306.style.display = "none"; // hide
#
#                 toggle_input_1983238306 = function() {
#                     if (input_1983238306.style.display == "none") {
#                         input_1983238306.style.display = ""; // show
#                         link_1983238306.innerHTML = "Hide Input";
#                     } else {
#                         input_1983238306.style.display = "none"; // hide
#                         link_1983238306.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1983238306 = $("a[id='1983238306']");
#                 var cell_1983238306 = link_1983238306.parents("div.cell:first");
#                 if (cell_1983238306.length == 0) {
#                     cell_1983238306 = link_1983238306.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1983238306 = cell_1983238306.children("div.input");
#                 if (input_1983238306.length == 0) {
#                     input_1983238306 = cell_1983238306.prev("div.nbinput");
#                 }
#                 input_1983238306.hide();
#
#                 toggle_input_1983238306 = function() {
#                     if (input_1983238306.is(':hidden')) {
#                         input_1983238306.slideDown();
#                         link_1983238306[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1983238306.slideUp();
#                         link_1983238306[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel("Neuron")
ax.set_xlabel("Time (s)")
hide_input()
# Out:
#         <a id="1829255552" href="javascript:toggle_input_1829255552()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1829255552;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1829255552 = document.getElementById("1829255552");
#                 var cell = link_1829255552;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1829255552;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1829255552 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1829255552 = cell.previousElementSibling;
#                 }
#                 input_1829255552.style.display = "none"; // hide
#
#                 toggle_input_1829255552 = function() {
#                     if (input_1829255552.style.display == "none") {
#                         input_1829255552.style.display = ""; // show
#                         link_1829255552.innerHTML = "Hide Input";
#                     } else {
#                         input_1829255552.style.display = "none"; // hide
#                         link_1829255552.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1829255552 = $("a[id='1829255552']");
#                 var cell_1829255552 = link_1829255552.parents("div.cell:first");
#                 if (cell_1829255552.length == 0) {
#                     cell_1829255552 = link_1829255552.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1829255552 = cell_1829255552.children("div.input");
#                 if (input_1829255552.length == 0) {
#                     input_1829255552 = cell_1829255552.prev("div.nbinput");
#                 }
#                 input_1829255552.hide();
#
#                 toggle_input_1829255552 = function() {
#                     if (input_1829255552.is(':hidden')) {
#                         input_1829255552.slideDown();
#                         link_1829255552[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1829255552.slideUp();
#                         link_1829255552[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons)
)
hide_input()
# Out:
#         <a id="1604125945" href="javascript:toggle_input_1604125945()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1604125945;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1604125945 = document.getElementById("1604125945");
#                 var cell = link_1604125945;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1604125945;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1604125945 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1604125945 = cell.previousElementSibling;
#                 }
#                 input_1604125945.style.display = "none"; // hide
#
#                 toggle_input_1604125945 = function() {
#                     if (input_1604125945.style.display == "none") {
#                         input_1604125945.style.display = ""; // show
#                         link_1604125945.innerHTML = "Hide Input";
#                     } else {
#                         input_1604125945.style.display = "none"; // hide
#                         link_1604125945.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1604125945 = $("a[id='1604125945']");
#                 var cell_1604125945 = link_1604125945.parents("div.cell:first");
#                 if (cell_1604125945.length == 0) {
#                     cell_1604125945 = link_1604125945.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1604125945 = cell_1604125945.children("div.input");
#                 if (input_1604125945.length == 0) {
#                     input_1604125945 = cell_1604125945.prev("div.nbinput");
#                 }
#                 input_1604125945.hide();
#
#                 toggle_input_1604125945 = function() {
#                     if (input_1604125945.is(':hidden')) {
#                         input_1604125945.slideDown();
#                         link_1604125945[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1604125945.slideUp();
#                         link_1604125945[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="163094424" href="javascript:toggle_input_163094424()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_163094424;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_163094424 = document.getElementById("163094424");
#                 var cell = link_163094424;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_163094424;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_163094424 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_163094424 = cell.previousElementSibling;
#                 }
#                 input_163094424.style.display = "none"; // hide
#
#                 toggle_input_163094424 = function() {
#                     if (input_163094424.style.display == "none") {
#                         input_163094424.style.display = ""; // show
#                         link_163094424.innerHTML = "Hide Input";
#                     } else {
#                         input_163094424.style.display = "none"; // hide
#                         link_163094424.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_163094424 = $("a[id='163094424']");
#                 var cell_163094424 = link_163094424.parents("div.cell:first");
#                 if (cell_163094424.length == 0) {
#                     cell_163094424 = link_163094424.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_163094424 = cell_163094424.children("div.input");
#                 if (input_163094424.length == 0) {
#                     input_163094424 = cell_163094424.prev("div.nbinput");
#                 }
#                 input_163094424.hide();
#
#                 toggle_input_163094424 = function() {
#                     if (input_163094424.is(':hidden')) {
#                         input_163094424.slideDown();
#                         link_163094424[0].innerHTML = "Hide Input";
#                     } else {
#                         input_163094424.slideUp();
#                         link_163094424[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="2046388614" href="javascript:toggle_input_2046388614()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2046388614;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2046388614 = document.getElementById("2046388614");
#                 var cell = link_2046388614;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2046388614;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2046388614 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2046388614 = cell.previousElementSibling;
#                 }
#                 input_2046388614.style.display = "none"; // hide
#
#                 toggle_input_2046388614 = function() {
#                     if (input_2046388614.style.display == "none") {
#                         input_2046388614.style.display = ""; // show
#                         link_2046388614.innerHTML = "Hide Input";
#                     } else {
#                         input_2046388614.style.display = "none"; // hide
#                         link_2046388614.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2046388614 = $("a[id='2046388614']");
#                 var cell_2046388614 = link_2046388614.parents("div.cell:first");
#                 if (cell_2046388614.length == 0) {
#                     cell_2046388614 = link_2046388614.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2046388614 = cell_2046388614.children("div.input");
#                 if (input_2046388614.length == 0) {
#                     input_2046388614 = cell_2046388614.prev("div.nbinput");
#                 }
#                 input_2046388614.hide();
#
#                 toggle_input_2046388614 = function() {
#                     if (input_2046388614.is(':hidden')) {
#                         input_2046388614.slideDown();
#                         link_2046388614[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2046388614.slideUp();
#                         link_2046388614[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="526479786" href="javascript:toggle_input_526479786()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_526479786;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_526479786 = document.getElementById("526479786");
#                 var cell = link_526479786;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_526479786;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_526479786 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_526479786 = cell.previousElementSibling;
#                 }
#                 input_526479786.style.display = "none"; // hide
#
#                 toggle_input_526479786 = function() {
#                     if (input_526479786.style.display == "none") {
#                         input_526479786.style.display = ""; // show
#                         link_526479786.innerHTML = "Hide Input";
#                     } else {
#                         input_526479786.style.display = "none"; // hide
#                         link_526479786.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_526479786 = $("a[id='526479786']");
#                 var cell_526479786 = link_526479786.parents("div.cell:first");
#                 if (cell_526479786.length == 0) {
#                     cell_526479786 = link_526479786.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_526479786 = cell_526479786.children("div.input");
#                 if (input_526479786.length == 0) {
#                     input_526479786 = cell_526479786.prev("div.nbinput");
#                 }
#                 input_526479786.hide();
#
#                 toggle_input_526479786 = function() {
#                     if (input_526479786.is(':hidden')) {
#                         input_526479786.slideDown();
#                         link_526479786[0].innerHTML = "Hide Input";
#                     } else {
#                         input_526479786.slideUp();
#                         link_526479786[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize="medium")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1502307015" href="javascript:toggle_input_1502307015()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1502307015;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1502307015 = document.getElementById("1502307015");
#                 var cell = link_1502307015;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1502307015;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1502307015 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1502307015 = cell.previousElementSibling;
#                 }
#                 input_1502307015.style.display = "none"; // hide
#
#                 toggle_input_1502307015 = function() {
#                     if (input_1502307015.style.display == "none") {
#                         input_1502307015.style.display = ""; // show
#                         link_1502307015.innerHTML = "Hide Input";
#                     } else {
#                         input_1502307015.style.display = "none"; // hide
#                         link_1502307015.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1502307015 = $("a[id='1502307015']");
#                 var cell_1502307015 = link_1502307015.parents("div.cell:first");
#                 if (cell_1502307015.length == 0) {
#                     cell_1502307015 = link_1502307015.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1502307015 = cell_1502307015.children("div.input");
#                 if (input_1502307015.length == 0) {
#                     input_1502307015 = cell_1502307015.prev("div.nbinput");
#                 }
#                 input_1502307015.hide();
#
#                 toggle_input_1502307015 = function() {
#                     if (input_1502307015.is(':hidden')) {
#                         input_1502307015.slideDown();
#                         link_1502307015[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1502307015.slideUp();
#                         link_1502307015[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="97255466" href="javascript:toggle_input_97255466()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_97255466;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_97255466 = document.getElementById("97255466");
#                 var cell = link_97255466;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_97255466;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_97255466 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_97255466 = cell.previousElementSibling;
#                 }
#                 input_97255466.style.display = "none"; // hide
#
#                 toggle_input_97255466 = function() {
#                     if (input_97255466.style.display == "none") {
#                         input_97255466.style.display = ""; // show
#                         link_97255466.innerHTML = "Hide Input";
#                     } else {
#                         input_97255466.style.display = "none"; // hide
#                         link_97255466.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_97255466 = $("a[id='97255466']");
#                 var cell_97255466 = link_97255466.parents("div.cell:first");
#                 if (cell_97255466.length == 0) {
#                     cell_97255466 = link_97255466.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_97255466 = cell_97255466.children("div.input");
#                 if (input_97255466.length == 0) {
#                     input_97255466 = cell_97255466.prev("div.nbinput");
#                 }
#                 input_97255466.hide();
#
#                 toggle_input_97255466 = function() {
#                     if (input_97255466.is(':hidden')) {
#                         input_97255466.slideDown();
#                         link_97255466[0].innerHTML = "Hide Input";
#                     } else {
#                         input_97255466.slideUp();
#                         link_97255466[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1569386711" href="javascript:toggle_input_1569386711()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1569386711;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1569386711 = document.getElementById("1569386711");
#                 var cell = link_1569386711;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1569386711;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1569386711 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1569386711 = cell.previousElementSibling;
#                 }
#                 input_1569386711.style.display = "none"; // hide
#
#                 toggle_input_1569386711 = function() {
#                     if (input_1569386711.style.display == "none") {
#                         input_1569386711.style.display = ""; // show
#                         link_1569386711.innerHTML = "Hide Input";
#                     } else {
#                         input_1569386711.style.display = "none"; // hide
#                         link_1569386711.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1569386711 = $("a[id='1569386711']");
#                 var cell_1569386711 = link_1569386711.parents("div.cell:first");
#                 if (cell_1569386711.length == 0) {
#                     cell_1569386711 = link_1569386711.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1569386711 = cell_1569386711.children("div.input");
#                 if (input_1569386711.length == 0) {
#                     input_1569386711 = cell_1569386711.prev("div.nbinput");
#                 }
#                 input_1569386711.hide();
#
#                 toggle_input_1569386711 = function() {
#                     if (input_1569386711.is(':hidden')) {
#                         input_1569386711.slideDown();
#                         link_1569386711[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1569386711.slideUp();
#                         link_1569386711[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color="k")
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color="k")
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color="k")
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1715871211" href="javascript:toggle_input_1715871211()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1715871211;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1715871211 = document.getElementById("1715871211");
#                 var cell = link_1715871211;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1715871211;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1715871211 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1715871211 = cell.previousElementSibling;
#                 }
#                 input_1715871211.style.display = "none"; // hide
#
#                 toggle_input_1715871211 = function() {
#                     if (input_1715871211.style.display == "none") {
#                         input_1715871211.style.display = ""; // show
#                         link_1715871211.innerHTML = "Hide Input";
#                     } else {
#                         input_1715871211.style.display = "none"; // hide
#                         link_1715871211.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1715871211 = $("a[id='1715871211']");
#                 var cell_1715871211 = link_1715871211.parents("div.cell:first");
#                 if (cell_1715871211.length == 0) {
#                     cell_1715871211 = link_1715871211.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1715871211 = cell_1715871211.children("div.input");
#                 if (input_1715871211.length == 0) {
#                     input_1715871211 = cell_1715871211.prev("div.nbinput");
#                 }
#                 input_1715871211.hide();
#
#                 toggle_input_1715871211 = function() {
#                     if (input_1715871211.is(':hidden')) {
#                         input_1715871211.slideDown();
#                         link_1715871211[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1715871211.slideUp();
#                         link_1715871211[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel("Time (s)")

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
hide_input()
# Out:
#         <a id="1618017152" href="javascript:toggle_input_1618017152()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1618017152;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1618017152 = document.getElementById("1618017152");
#                 var cell = link_1618017152;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1618017152;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1618017152 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1618017152 = cell.previousElementSibling;
#                 }
#                 input_1618017152.style.display = "none"; // hide
#
#                 toggle_input_1618017152 = function() {
#                     if (input_1618017152.style.display == "none") {
#                         input_1618017152.style.display = ""; // show
#                         link_1618017152.innerHTML = "Hide Input";
#                     } else {
#                         input_1618017152.style.display = "none"; // hide
#                         link_1618017152.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1618017152 = $("a[id='1618017152']");
#                 var cell_1618017152 = link_1618017152.parents("div.cell:first");
#                 if (cell_1618017152.length == 0) {
#                     cell_1618017152 = link_1618017152.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1618017152 = cell_1618017152.children("div.input");
#                 if (input_1618017152.length == 0) {
#                     input_1618017152 = cell_1618017152.prev("div.nbinput");
#                 }
#                 input_1618017152.hide();
#
#                 toggle_input_1618017152 = function() {
#                     if (input_1618017152.is(':hidden')) {
#                         input_1618017152.slideDown();
#                         link_1618017152[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1618017152.slideUp();
#                         link_1618017152[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
